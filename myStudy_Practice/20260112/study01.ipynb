# %%
import this

# %% [markdown]
# ### 출력 (print)
#
# - 첫 단원에서는 **기본 print()의** 출력을 배웁니다
# - 향후 실흡 진행을 위한 정도만 배우고, 나중에 문자열 포맷팅에서 더 자세히 다룹니다.

# %%
print(type (True))
# Out:
# <class 'bool'>

# %%
print(type("문자"))
# Out:
# <class 'str'>

# %%
print(type(12345))
# Out:
# <class 'int'>

# %%
print("문자"*10)
# Out:
# 문자문자문자문자문자문자문자문자문자문자

# %%
print(type(True), False)
# Out:
# <class 'bool'> False

# %%
print(True +12)
# Out:
# 13

# %% [markdown]
# ### 변수 (Variable)
# - 데이터를 담는 그릇
# - file도 담을 수 있다

# %%
a = 1
a=2
a
# Out:
# 2

# %%
a=2
a
# Out:
# 2

# %%
a_a = 3
a_a
# Out:
# 3

# %%
b=1.1
type(b)
# Out:
# float

# %%
a == b
# Out:
# False

# %%
a==b
b=2

# %%
type(a) == type(b)
# Out:
# True

# %%
c='안녕'
c
# Out:
# '안녕'

# %%
d = '긴글입니' \
'다'
d
# Out:
# '긴글입니다'

# %%
import sys
